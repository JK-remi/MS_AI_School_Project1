# %% [markdown]
# # 서버 설정
# - 모바일과 구동할 서버(local PC)가 같은 wi-fi를 잡도록 해주세요

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # SimpleServer.py를 실행시켜 주세요.
# - F5 or Ctrl+F5

# %% [markdown]
# ![스크린샷 2024-07-26 092953.png](<attachment:스크린샷 2024-07-26 092953.png>)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 다음 화면과 같은내용이 터미널에 나온다면 서버 구동에 성공했습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 서버 동작 예시

# %% [markdown]
# ![image.png](attachment:image.png)
