# %% [markdown]
# # unity project setting
# - version: 2022.3.38f1
# - template(core): AR Mobile
#
# - [설치 및 프로젝트 세팅](https://www.youtube.com/watch?v=lSJwqfc9imU)

# %% [markdown]
# ![스크린샷 2024-07-26 090633.png](<attachment:스크린샷 2024-07-26 090633.png>)

# %% [markdown]
# # 다음과 같은 화면이 나온다면 프로젝트 생성에 성공했습니다.
# -(화면 구성은다를수 있습니다.)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # unity package를 import합니다.

# %% [markdown]
# ## unity project의 package를 다운받습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Assets>ImportPackage>CustomPackage...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 다운 받은 unity package 선택 후 열기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## import 해주세요

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 올바른 실행을 위해 unity를 재시작 해주세요.
# - Reload 클릭

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Build Setting - platform에 맞는 빌드 설정
# - [설치 및 프로젝트 세팅](https://www.youtube.com/watch?v=lSJwqfc9imU)

# %% [markdown]
# - File>BuildSettings

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 플랫폼을 설치할 환경에 맞게 설정해 주세요.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 선택한 후 switch platform을 클릭해 주세요. (시간 소요 예상)

# %% [markdown]
# # 선택이 완료 되면 unity 로고의 위치가 바뀐 것을 확인할 수 있습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 제 프로젝트의 빌드 세팅이니 참고해 주세요.
# - 개발자 모드로 디버깅을 위해 DevelopmentBuild로 진행했습니다.
# - 단순 빌드를 원하시면 DebelopmentBuild를 해제해주셔도 됩니다.

# %% [markdown]
# # build버튼을 누르고 생성된 apk파일을 디바이스에 옮겨 설치해 주세요.
# - 10분- 30분 시간이 소요될 것으로 예상됩니다.
# - iOS는 어떤식으로 설치되는지 확인 못한 점 양해 부탁드립니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # unity에서 실행할 경우

# %% [markdown]
# ## 재생 버튼을 눌러주세요.
# - 단축키: Ctrl+P

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Hierachy에서 Plane선택 후 활성화
# - 테스트를 위해 화면에 비출 이미지 입니다.
# - Hierachy에서 Plane을 찾아서 선택 후
# - Inspector에서 체크박스를 활성화 시켜주세요.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 게임화면에 다음과 같은 화면이 나오면 성공

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Game 창에서는 일반 RPG에서 처럼 이동과 카메라 전환이 가능하니 참고해 주세요.
# - 마우스 우클릭 상태로 이동 - 화면 전환
# - 'W''A''S''D' 이동
# - 이동이 기존의 설정된 AR 반경 내에서만 가능한 점 양해 부탁드립니다.
